# %%
for i in range(1, 4):
    for j in range(1, 4):
        if i ==j:
            continue
        print(i, "*", j, "=", i*j)
# Out:
# 1 * 2 = 2
# 1 * 3 = 3
# 2 * 1 = 2
# 2 * 3 = 6
# 3 * 1 = 3
# 3 * 2 = 6

# %%
for i in range(1, 11):
    for j in range(2):
        if i ==j:
            continue
        print(i, "*", j, "=", i*j)
# Out:
# 1 * 0 = 0
# 2 * 0 = 0
# 2 * 1 = 2
# 3 * 0 = 0
# 3 * 1 = 3
# 4 * 0 = 0
# 4 * 1 = 4
# 5 * 0 = 0
# 5 * 1 = 5
# 6 * 0 = 0
# 6 * 1 = 6
# 7 * 0 = 0
# 7 * 1 = 7
# 8 * 0 = 0
# 8 * 1 = 8
# 9 * 0 = 0
# 9 * 1 = 9
# 10 * 0 = 0
# 10 * 1 = 10
