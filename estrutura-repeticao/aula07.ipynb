# %%
for i in range(1, 4):
    for j in range(1, 4):
        if i ==j:
            continue
        print(i, "*", j, "=", i*j)
# Out:
# 1 * 2 = 2
# 1 * 3 = 3
# 2 * 1 = 2
# 2 * 3 = 6
# 3 * 1 = 3
# 3 * 2 = 6

# %%
for i in range(1, 11):
    for j in range(2):
        if i ==j:
            continue
        print(i, "*", j, "=", i*j)
